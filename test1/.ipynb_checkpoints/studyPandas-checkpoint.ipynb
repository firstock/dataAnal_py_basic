# %% [markdown]
# ### pands
#
# [판다이해](https://pandas.pydata.org/pandas-docs/stable/10min.html)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s= pd.Series([1,2,4,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    2.0
# 2    4.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates= pd.date_range('20171122',periods=6)
dates
# Out:
# DatetimeIndex(['2017-11-22', '2017-11-23', '2017-11-24', '2017-11-25',
#                '2017-11-26', '2017-11-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2= pd.DataFrame({
    'A': 1.,
    'B': pd.Timestamp('20171122'),
    'C': pd.Series(1,index= list(range(4)), dtype='float32'),
    'D': np.array([3]*4,dtype='int32'),
    'E': pd.Categorical(["test","train","test","train"]),
    'F': 'foo'
})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2017-11-22  1.0  3   test  foo
# 1  1.0 2017-11-22  1.0  3  train  foo
# 2  1.0 2017-11-22  1.0  3   test  foo
# 3  1.0 2017-11-22  1.0  3  train  foo

# %%
df= pd.DataFrame(np.random.randn(6,4), index= dates, columns= list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2017-11-22  1.923885 -1.964820 -0.251724 -0.028749
# 2017-11-23  0.914040  1.398569  0.978653  0.415141
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829
# 2017-11-25  0.946394  0.878373  0.425503  0.231049
# 2017-11-26  0.037137 -0.003483 -0.943790  0.634803
# 2017-11-27 -0.449468 -0.688341 -1.214629  0.527861

# %%
df2.dtypes

df2.shape
df2.head(2)
df2.tail(2)
df.index
df.columns
df.values
df.describe
df.T
# Out:
#    2017-11-22  2017-11-23  2017-11-24  2017-11-25  2017-11-26  2017-11-27
# A    1.923885    0.914040    0.851079    0.946394    0.037137   -0.449468
# B   -1.964820    1.398569   -1.769156    0.878373   -0.003483   -0.688341
# C   -0.251724    0.978653    0.129640    0.425503   -0.943790   -1.214629
# D   -0.028749    0.415141    0.872829    0.231049    0.634803    0.527861

# %% [markdown]
# ### 쓸만

# %%
df.sort_index(axis=1, ascending=False)
df.sort_values(by='A') # col기준 오름차순
# Out:
#                    A         B         C         D
# 2017-11-27 -0.449468 -0.688341 -1.214629  0.527861
# 2017-11-26  0.037137 -0.003483 -0.943790  0.634803
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829
# 2017-11-23  0.914040  1.398569  0.978653  0.415141
# 2017-11-25  0.946394  0.878373  0.425503  0.231049
# 2017-11-22  1.923885 -1.964820 -0.251724 -0.028749

# %%
# df[df['A']<0]
# df.loc[df['A']<0,"Am"]= True

# %%
df
# Out:
#                    A         B         C         D
# 2017-11-22  1.923885 -1.964820 -0.251724 -0.028749
# 2017-11-23  0.914040  1.398569  0.978653  0.415141
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829
# 2017-11-25  0.946394  0.878373  0.425503  0.231049
# 2017-11-26  0.037137 -0.003483 -0.943790  0.634803
# 2017-11-27 -0.449468 -0.688341 -1.214629  0.527861

# %%
# df.drop("Am")
# del df["Am"]

# %%
df[0:2] #[0,2)
# Out:
#                    A         B         C         D
# 2017-11-22  1.923885 -1.964820 -0.251724 -0.028749
# 2017-11-23  0.914040  1.398569  0.978653  0.415141

# %% [markdown]
# ### line 21

# %%
df['20171123':'20171123']
# Out:
#                   A         B         C         D
# 2017-11-23  0.91404  1.398569  0.978653  0.415141

# %%
df.loc[dates[0]]
# dates[0]
df.loc['20171122']
# Out:
# A    1.923885
# B   -1.964820
# C   -0.251724
# D   -0.028749
# Name: 2017-11-22 00:00:00, dtype: float64

# %%
df.loc[:,['A','C']]
df.loc['20171124',:]
# Out:
# A    0.851079
# B   -1.769156
# C    0.129640
# D    0.872829
# Name: 2017-11-24 00:00:00, dtype: float64

# %%
df.loc['20171123':'20171123',['B','C']]
# Out:
#                    B         C
# 2017-11-23  1.398569  0.978653

# %%
df.loc['20171122',['C','B']]
# Out:
# C   -0.251724
# B   -1.964820
# Name: 2017-11-22 00:00:00, dtype: float64

# %%
df
# Out:
#                    A         B         C         D
# 2017-11-22  1.923885 -1.964820 -0.251724 -0.028749
# 2017-11-23  0.914040  1.398569  0.978653  0.415141
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829
# 2017-11-25  0.946394  0.878373  0.425503  0.231049
# 2017-11-26  0.037137 -0.003483 -0.943790  0.634803
# 2017-11-27 -0.449468 -0.688341 -1.214629  0.527861

# %%
df.loc[dates[0],'D']
# Out:
# -0.0287488665710951

# %%
df.iloc[1]
help(df.iloc)
df.iloc.__doc__
# Out:
# Help on _iLocIndexer in module pandas.core.indexing object:
#
# class _iLocIndexer(_LocationIndexer)
#  |  Purely integer-location based indexing for selection by position.
#  |
#  |  ``.iloc[]`` is primarily integer position based (from ``0`` to
#  |  ``length-1`` of the axis), but may also be used with a boolean
#  |  array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - An integer, e.g. ``5``.
#  |  - A list or array of integers, e.g. ``[4, 3, 0]``.
#  |  - A slice object with ints, e.g. ``1:7``.
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series, DataFrame
#  |    or Panel) and that returns valid output for indexing (one of the above)
#  |
#  |  ``.iloc`` will raise ``IndexError`` if a requested indexer is
#  |  out-of-bounds, except *slice* indexers which allow out-of-bounds
#  |  indexing (this conforms with python/numpy *slice* semantics).
#  |
#  |  See more at :ref:`Selection by Position <indexing.integer>`
#  |
# ...

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2017-11-25  0.946394  0.878373
# 2017-11-26  0.037137 -0.003483

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2017-11-23  0.914040  0.978653
# 2017-11-24  0.851079  0.129640
# 2017-11-26  0.037137 -0.943790

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2017-11-23  0.914040  1.398569  0.978653  0.415141
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2017-11-22 -1.964820 -0.251724
# 2017-11-23  1.398569  0.978653
# 2017-11-24 -1.769156  0.129640
# 2017-11-25  0.878373  0.425503
# 2017-11-26 -0.003483 -0.943790
# 2017-11-27 -0.688341 -1.214629

# %%
df.iloc[1,1]
# Out:
# 1.3985694201984737

# %%
df[df.A>0]
# df.A>0
# Out:
#                    A         B         C         D
# 2017-11-22  1.923885 -1.964820 -0.251724 -0.028749
# 2017-11-23  0.914040  1.398569  0.978653  0.415141
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829
# 2017-11-25  0.946394  0.878373  0.425503  0.231049
# 2017-11-26  0.037137 -0.003483 -0.943790  0.634803

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2017-11-22  1.923885       NaN       NaN       NaN
# 2017-11-23  0.914040  1.398569  0.978653  0.415141
# 2017-11-24  0.851079       NaN  0.129640  0.872829
# 2017-11-25  0.946394  0.878373  0.425503  0.231049
# 2017-11-26  0.037137       NaN       NaN  0.634803
# 2017-11-27       NaN       NaN       NaN  0.527861

# %%
df2= df.copy()
df2
# Out:
#                    A         B         C         D
# 2017-11-22  1.923885 -1.964820 -0.251724 -0.028749
# 2017-11-23  0.914040  1.398569  0.978653  0.415141
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829
# 2017-11-25  0.946394  0.878373  0.425503  0.231049
# 2017-11-26  0.037137 -0.003483 -0.943790  0.634803
# 2017-11-27 -0.449468 -0.688341 -1.214629  0.527861

# %%
df2['E']= ['one','one','two','three','four','three']
df2
# Out:
#                    A         B         C         D      E
# 2017-11-22  1.923885 -1.964820 -0.251724 -0.028749    one
# 2017-11-23  0.914040  1.398569  0.978653  0.415141    one
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829    two
# 2017-11-25  0.946394  0.878373  0.425503  0.231049  three
# 2017-11-26  0.037137 -0.003483 -0.943790  0.634803   four
# 2017-11-27 -0.449468 -0.688341 -1.214629  0.527861  three

# %%
df2[df2['E'].isin(['one','two'])]
# Out:
#                    A         B         C         D    E
# 2017-11-22  1.923885 -1.964820 -0.251724 -0.028749  one
# 2017-11-23  0.914040  1.398569  0.978653  0.415141  one
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829  two

# %%
s1= pd.Series([1,2,3,4,5,6],index=pd.date_range('20171122',periods=6))
s1
# Out:
# 2017-11-22    1
# 2017-11-23    2
# 2017-11-24    3
# 2017-11-25    4
# 2017-11-26    5
# 2017-11-27    6
# Freq: D, dtype: int64

# %%
df['F']=s1
# 행 수가 맞아야 들어감. <-> 전부 NaN
df
# Out:
#                    A         B         C         D  F
# 2017-11-22  1.923885 -1.964820 -0.251724 -0.028749  1
# 2017-11-23  0.914040  1.398569  0.978653  0.415141  2
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829  3
# 2017-11-25  0.946394  0.878373  0.425503  0.231049  4
# 2017-11-26  0.037137 -0.003483 -0.943790  0.634803  5
# 2017-11-27 -0.449468 -0.688341 -1.214629  0.527861  6

# %%
df.at[dates[0],'A']= 0
df
# Out:
#                    A         B         C         D  F
# 2017-11-22  0.000000 -1.964820 -0.251724 -0.028749  1
# 2017-11-23  0.914040  1.398569  0.978653  0.415141  2
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829  3
# 2017-11-25  0.946394  0.878373  0.425503  0.231049  4
# 2017-11-26  0.037137 -0.003483 -0.943790  0.634803  5
# 2017-11-27 -0.449468 -0.688341 -1.214629  0.527861  6

# %%
help(df.iat)
# Out:
# Help on _iAtIndexer in module pandas.core.indexing object:
#
# class _iAtIndexer(_ScalarAccessIndexer)
#  |  Fast integer location scalar accessor.
#  |
#  |  Similarly to ``iloc``, ``iat`` provides **integer** based lookups.
#  |  You can also set using these indexers.
#  |
#  |  Method resolution order:
#  |      _iAtIndexer
#  |      _ScalarAccessIndexer
#  |      _NDFrameIndexer
#  |      builtins.object
#  |
#  |  Methods inherited from _ScalarAccessIndexer:
#  |
#  |  __getitem__(self, key)
#  |
#  |  __setitem__(self, key, value)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _NDFrameIndexer:
#  |
#  |  __call__(self, axis=None)
#  |      Call self as a function.
#  |
#  |  __init__(self, obj, name)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |
#  |  ----------------------------------------------------------------------
# ...

# %%
df.iat[0,1]=0
df
# Out:
#                    A         B         C         D  F
# 2017-11-22  0.000000  0.000000 -0.251724 -0.028749  1
# 2017-11-23  0.914040  1.398569  0.978653  0.415141  2
# 2017-11-24  0.851079 -1.769156  0.129640  0.872829  3
# 2017-11-25  0.946394  0.878373  0.425503  0.231049  4
# 2017-11-26  0.037137 -0.003483 -0.943790  0.634803  5
# 2017-11-27 -0.449468 -0.688341 -1.214629  0.527861  6

# %%
df.loc[:,'D']= np.array([5]*len(df))
df
# Out:
#                    A         B         C  D  F
# 2017-11-22  0.000000  0.000000 -0.251724  5  1
# 2017-11-23  0.914040  1.398569  0.978653  5  2
# 2017-11-24  0.851079 -1.769156  0.129640  5  3
# 2017-11-25  0.946394  0.878373  0.425503  5  4
# 2017-11-26  0.037137 -0.003483 -0.943790  5  5
# 2017-11-27 -0.449468 -0.688341 -1.214629  5  6

# %%
len(df)
# Out:
# 6

# %%
df2= df.copy()
df2
# Out:
#                    A         B         C  D  F
# 2017-11-22  0.000000  0.000000 -0.251724  5  1
# 2017-11-23  0.914040  1.398569  0.978653  5  2
# 2017-11-24  0.851079 -1.769156  0.129640  5  3
# 2017-11-25  0.946394  0.878373  0.425503  5  4
# 2017-11-26  0.037137 -0.003483 -0.943790  5  5
# 2017-11-27 -0.449468 -0.688341 -1.214629  5  6

# %%
df2[df2>0]= -df2
df2
# Out:
#                    A         B         C  D  F
# 2017-11-22  0.000000  0.000000 -0.251724 -5 -1
# 2017-11-23 -0.914040 -1.398569 -0.978653 -5 -2
# 2017-11-24 -0.851079 -1.769156 -0.129640 -5 -3
# 2017-11-25 -0.946394 -0.878373 -0.425503 -5 -4
# 2017-11-26 -0.037137 -0.003483 -0.943790 -5 -5
# 2017-11-27 -0.449468 -0.688341 -1.214629 -5 -6

# %%
df1= df.reindex(index= dates[0:4], columns= list(df.columns)+['E'])
df1
# Out:
#                    A         B         C  D  F   E
# 2017-11-22  0.000000  0.000000 -0.251724  5  1 NaN
# 2017-11-23  0.914040  1.398569  0.978653  5  2 NaN
# 2017-11-24  0.851079 -1.769156  0.129640  5  3 NaN
# 2017-11-25  0.946394  0.878373  0.425503  5  4 NaN

# %%
# !pwd
# Out:
# /c/myjupyter/test1
