# %% [markdown]
# [판다스10분컷_naver](http://optimist20.blog.me/221216444128)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1= pd.read_csv('data/startup_funding.csv')

# %%
df1
# Out:
#        SNo         Date       StartupName   IndustryVertical  \
# 0        0   01/08/2017          TouchKin         Technology
# 1        1   02/08/2017           Ethinos         Technology
# 2        2   02/08/2017      Leverage Edu  Consumer Internet
# 3        3   02/08/2017              Zepo  Consumer Internet
# 4        4   02/08/2017      Click2Clinic  Consumer Internet
# 5        5   01/07/2017     Billion Loans  Consumer Internet
# 6        6   03/07/2017  Ecolibriumenergy         Technology
# 7        7   04/07/2017             Droom          eCommerce
# 8        8   05/07/2017         Jumbotail          eCommerce
# 9        9   05/07/2017            Moglix          eCommerce
# 10      10   05/07/2017        Timesaverz  Consumer Internet
# 11      11   06/07/2017            Minjar         Technology
# 12      12   06/07/2017       MyCity4kids  Consumer Internet
# 13      13   07/07/2017          Clip App  Consumer Internet
# ...

# %%
s= pd.Series([1,3,5,np.nan,6,8]); s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates= pd.date_range('20180226', periods= 6); dates
# Out:
# DatetimeIndex(['2018-02-26', '2018-02-27', '2018-02-28', '2018-03-01',
#                '2018-03-02', '2018-03-03'],
#               dtype='datetime64[ns]', freq='D')

# %%
df= pd.DataFrame(np.random.randn(6,4), index= dates, columns= list('ABCD')); df
# Out:
#                    A         B         C         D
# 2018-02-26  0.523412 -0.170109  0.213200 -0.388757
# 2018-02-27 -1.241708  0.136762  0.297534  1.164843
# 2018-02-28 -0.675726  1.230830 -0.067472  0.814116
# 2018-03-01  0.559281  0.442223 -0.107683  1.355961
# 2018-03-02  1.422303  0.348912 -1.763893 -1.854494
# 2018-03-03  0.592398  0.518544  1.801900  0.011119

# %%
df2= pd.DataFrame({'A': 1.
                  , 'B': pd.Timestamp('20180226')
                  #, 'C': pd.Series(1, index= list(range(4)), dtype= 'float32')
                  ,'C': pd.Series(1, index= range(4), dtype= 'float32')
                   ,'D': np.array([3]* 4, dtype= 'int32')
                   ,'E': pd.Categorical(["text","train","test","train"])
                   ,'F': 'foo'
                  })
                   
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2018-02-26  1.0  3   text  foo
# 1  1.0 2018-02-26  1.0  3  train  foo
# 2  1.0 2018-02-26  1.0  3   test  foo
# 3  1.0 2018-02-26  1.0  3  train  foo

# %%
print(range(4))
print(list(range(4)))
# Out:
# range(0, 4)
# [0, 1, 2, 3]

# %%
# df2.types 엄썽
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
print(df1.dtypes)
print(df1.head(1))
# Out:
# SNo                  int64
# Date                object
# StartupName         object
# IndustryVertical    object
# SubVertical         object
# CityLocation        object
# InvestorsName       object
# InvestmentType      object
# AmountInUSD         object
# Remarks             object
# dtype: object
#    SNo        Date StartupName IndustryVertical               SubVertical  \
# 0    0  01/08/2017    TouchKin       Technology  Predictive Care Platform
#
#   CityLocation InvestorsName  InvestmentType AmountInUSD Remarks
# 0    Bangalore   Kae Capital  Private Equity   1,300,000     NaN

# %%
print(df2.shape)
# Out:
# (4, 6)

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of      A          B    C  D      E    F
# 0  1.0 2018-02-26  1.0  3   text  foo
# 1  1.0 2018-02-26  1.0  3  train  foo
# 2  1.0 2018-02-26  1.0  3   test  foo
# 3  1.0 2018-02-26  1.0  3  train  foo>

# %%
df.head(4)
# Out:
#                    A         B         C         D
# 2018-02-26  0.523412 -0.170109  0.213200 -0.388757
# 2018-02-27 -1.241708  0.136762  0.297534  1.164843
# 2018-02-28 -0.675726  1.230830 -0.067472  0.814116
# 2018-03-01  0.559281  0.442223 -0.107683  1.355961

# %%
df.tail() # 5개
# Out:
#                    A         B         C         D
# 2018-02-27 -1.241708  0.136762  0.297534  1.164843
# 2018-02-28 -0.675726  1.230830 -0.067472  0.814116
# 2018-03-01  0.559281  0.442223 -0.107683  1.355961
# 2018-03-02  1.422303  0.348912 -1.763893 -1.854494
# 2018-03-03  0.592398  0.518544  1.801900  0.011119

# %%
df.index
# Out:
# DatetimeIndex(['2018-02-26', '2018-02-27', '2018-02-28', '2018-03-01',
#                '2018-03-02', '2018-03-03'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.52341205, -0.1701091 ,  0.2132003 , -0.38875678],
#        [-1.24170802,  0.1367615 ,  0.29753361,  1.16484298],
#        [-0.67572643,  1.23082983, -0.06747167,  0.81411635],
#        [ 0.55928144,  0.44222336, -0.10768252,  1.35596102],
#        [ 1.42230302,  0.34891211, -1.76389294, -1.8544935 ],
#        [ 0.5923979 ,  0.5185442 ,  1.80189987,  0.01111925]])

# %%
df1.values #중간은 생략하고 처음 3, 마지막 3개
# Out:
# array([[0, '01/08/2017', 'TouchKin', ..., 'Private Equity', '1,300,000',
#         nan],
#        [1, '02/08/2017', 'Ethinos', ..., 'Private Equity', nan, nan],
#        [2, '02/08/2017', 'Leverage Edu', ..., 'Seed Funding', nan, nan],
#        ...,
#        [2369, '30/01/2015', 'Mad Street Den', ..., 'Private Equity',
#         '1,500,000', nan],
#        [2370, '30/01/2015', 'Simplotel', ..., 'Private Equity', nan,
#         'Strategic Funding, Minority stake'],
#        [2371, '31/01/2015', 'couponmachine.in', ..., 'Seed Funding',
#         '140,000', nan]], dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.196660  0.417860  0.062264  0.183798
# std    0.972320  0.469282  1.138862  1.203826
# min   -1.241708 -0.170109 -1.763893 -1.854494
# 25%   -0.375942  0.189799 -0.097630 -0.288788
# 50%    0.541347  0.395568  0.072864  0.412618
# 75%    0.584119  0.499464  0.276450  1.077161
# max    1.422303  1.230830  1.801900  1.355961

# %%
df.describe # () 붙여야 원하는 게 나옴
# Out:
# <bound method NDFrame.describe of                    A         B         C         D
# 2018-02-26  0.523412 -0.170109  0.213200 -0.388757
# 2018-02-27 -1.241708  0.136762  0.297534  1.164843
# 2018-02-28 -0.675726  1.230830 -0.067472  0.814116
# 2018-03-01  0.559281  0.442223 -0.107683  1.355961
# 2018-03-02  1.422303  0.348912 -1.763893 -1.854494
# 2018-03-03  0.592398  0.518544  1.801900  0.011119>

# %%
df1.describe() #SNo 는 빼고 보고 싶은데, 나머지 object 취급은 숫자가 아니라 안 나오는 듯
# Out:
#                SNo
# count  2372.000000
# mean   1185.500000
# std     684.881742
# min       0.000000
# 25%     592.750000
# 50%    1185.500000
# 75%    1778.250000
# max    2371.000000

# %%
# df1.head(1)
# df1.replace(',','') - 이런식으로 안 됨. AnountInUSD좀..
df1.head(1)
# Out:
#    SNo        Date StartupName IndustryVertical               SubVertical  \
# 0    0  01/08/2017    TouchKin       Technology  Predictive Care Platform
#
#   CityLocation InvestorsName  InvestmentType AmountInUSD Remarks
# 0    Bangalore   Kae Capital  Private Equity   1,300,000     NaN

# %%
dft= df.T; dft
# Out:
#    2018-02-26  2018-02-27  2018-02-28  2018-03-01  2018-03-02  2018-03-03
# A    0.523412   -1.241708   -0.675726    0.559281    1.422303    0.592398
# B   -0.170109    0.136762    1.230830    0.442223    0.348912    0.518544
# C    0.213200    0.297534   -0.067472   -0.107683   -1.763893    1.801900
# D   -0.388757    1.164843    0.814116    1.355961   -1.854494    0.011119

# %%
df.head(1) # df.T 해도 원본은 변하지 않았다
# Out:
#                    A         B       C         D
# 2018-02-26  0.523412 -0.170109  0.2132 -0.388757

# %% [markdown]
# ##### 원본이 변하지 않는다? 객체를 값으로써 저장하는 게 아니라, 그저 가리킬 뿐
# https://wikidocs.net/18

# %%
import sys
a= 3
sys.getrefcount(a) # a 라는 정수형 객체에 참조 개수가 몇 개 있는지
# Out:
# 1484

# %%
b= 3
sys.getrefcount(b)
# Out:
# 1480

# %%
sys.getrefcount(dft)
# Out:
# 6

# %%
sys.getrefcount(df)
# Out:
# 8

# %% [markdown]
# #####  다시 pandas

# %%
df.head()
# Out:
#                    A         B         C         D
# 2018-02-26  0.523412 -0.170109  0.213200 -0.388757
# 2018-02-27 -1.241708  0.136762  0.297534  1.164843
# 2018-02-28 -0.675726  1.230830 -0.067472  0.814116
# 2018-03-01  0.559281  0.442223 -0.107683  1.355961
# 2018-03-02  1.422303  0.348912 -1.763893 -1.854494

# %%
df.sort_index()
# Out:
#                    A         B         C         D
# 2018-02-26  0.523412 -0.170109  0.213200 -0.388757
# 2018-02-27 -1.241708  0.136762  0.297534  1.164843
# 2018-02-28 -0.675726  1.230830 -0.067472  0.814116
# 2018-03-01  0.559281  0.442223 -0.107683  1.355961
# 2018-03-02  1.422303  0.348912 -1.763893 -1.854494
# 2018-03-03  0.592398  0.518544  1.801900  0.011119

# %%
df.sort_index(axis=1, ascending= False) #칼럼 DCBA
# Out:
#                    D         C         B         A
# 2018-02-26 -0.388757  0.213200 -0.170109  0.523412
# 2018-02-27  1.164843  0.297534  0.136762 -1.241708
# 2018-02-28  0.814116 -0.067472  1.230830 -0.675726
# 2018-03-01  1.355961 -0.107683  0.442223  0.559281
# 2018-03-02 -1.854494 -1.763893  0.348912  1.422303
# 2018-03-03  0.011119  1.801900  0.518544  0.592398

# %%
df.sort_index(axis=1, ascending= True) #칼럼 ABCD
# Out:
#                    A         B         C         D
# 2018-02-26  0.523412 -0.170109  0.213200 -0.388757
# 2018-02-27 -1.241708  0.136762  0.297534  1.164843
# 2018-02-28 -0.675726  1.230830 -0.067472  0.814116
# 2018-03-01  0.559281  0.442223 -0.107683  1.355961
# 2018-03-02  1.422303  0.348912 -1.763893 -1.854494
# 2018-03-03  0.592398  0.518544  1.801900  0.011119
