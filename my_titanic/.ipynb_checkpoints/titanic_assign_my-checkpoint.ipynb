# %%
import pandas as pd

# %%
train= pd.read_csv("data/train.csv", index_col= "PassengerId")

# %%
print(train.shape)
train.head()
# Out:
# (891, 11)
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 1. train에서 1) 전체 생존률, 2) 생존자 총인원, 3) 사망자 총인원

# %%
survived= train.Survived.sum()
passenger_tot= train.Survived.count()

# %%
print(survived)
print(train.Survived.value_counts())
print(train.Survived.value_counts()[1])
# Out:
# 342
# 0    549
# 1    342
# Name: Survived, dtype: int64
# 342

# %%
survived_rate= survived/ passenger_tot* 100

# %%
print(passenger_tot- survived)
print(train.Survived.value_counts()[0])
# Out:
# 549
# 549

# %%
dead_tot2= passenger_tot- survived

# %%
print(f"생존률\t\t{survived_rate:.3f}%")
print(f"생존인원\t{survived}")
print(f"사망인원\t{dead_tot2}")
# Out:
# 생존률		38.384%
# 생존인원	342
# 사망인원	549

# %% [markdown]
# ### 2. Survived 칼럼값을 사람이 이해하기 좋도록

# %%
fS= lambda x: 'live' if x==1 else 'dead'

# %%
train["Survived_humanized"]= train.Survived.map(fS)

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#             Survived_humanized
# PassengerId
# 1                         dead
# 2                         live
# 3                         live
# 4                         live
# 5                         dead

# %% [markdown]
# ### 3. Pclass 칼럼값을 사람이 이해하기 좋도록

# %%
train.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# 뭔 값인지 알기: [data overview](https://www.kaggle.com/c/titanic/data)
# - 1 FirstClass
# - 2 SecondClass
# - 3 ThirdClass

# %%
pd.pivot_table(data= train, index= "Pclass", values= "Survived")
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
fPc= lambda x: 'FirstClass' if x==1 else ('SecondClass' if x==2 else 'ThirdClass')

# %%
train["Pclass_humanized"]= train.Pclass.map(fPc)

# %%
train[["Pclass", "Pclass_humanized"]].head(10)
# Out:
#              Pclass Pclass_humanized
# PassengerId
# 1                 3       ThirdClass
# 2                 1       FirstClass
# 3                 3       ThirdClass
# 4                 1       FirstClass
# 5                 3       ThirdClass
# 6                 3       ThirdClass
# 7                 1       FirstClass
# 8                 3       ThirdClass
# 9                 3       ThirdClass
# 10                2      SecondClass

# %%
pd.pivot_table(data= train, index=["Pclass","Pclass_humanized"], values="Survived")
# Out:
#                          Survived
# Pclass Pclass_humanized
# 1      FirstClass        0.629630
# 2      SecondClass       0.472826
# 3      ThirdClass        0.242363

# %% [markdown]
# ### 4. Embarked 칼럼 값을 직관적으로 바꾸기
# C = Cherbourg, Q = Queenstown, S = Southampton

# %%
train.Embarked.head()
# Out:
# PassengerId
# 1    S
# 2    C
# 3    S
# 4    S
# 5    S
# Name: Embarked, dtype: object

# %%
fEm= lambda x: 'Cherbourg' if 'C'==x else ('Queenstown' if 'Q'==x else 'Southampton')

# %%
train["Embarked_humanized"]= train.Embarked.map(fEm)

# %%
train[['Embarked','Embarked_humanized', 'Survived']].head(6)
# Out:
#             Embarked Embarked_humanized  Survived
# PassengerId
# 1                  S        Southampton         0
# 2                  C          Cherbourg         1
# 3                  S        Southampton         1
# 4                  S        Southampton         1
# 5                  S        Southampton         0
# 6                  Q         Queenstown         0

# %%
print(train.columns.map)
train.columns.map(type)
# Out:
# <bound method Index.map of Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Survived_humanized', 'Pclass_humanized',
#        'Embarked_humanized'],
#       dtype='object')>
# Index([<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,
#        <class 'str'>, <class 'str'>],
#       dtype='object')

# %%
train.head(1)
# Out:
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#              Parch     Ticket  Fare Cabin Embarked Survived_humanized  \
# PassengerId
# 1                0  A/5 21171  7.25   NaN        S               dead
#
#             Pclass_humanized Embarked_humanized
# PassengerId
# 1                 ThirdClass        Southampton

# %%
pd.pivot_table(data= train, index=["Embarked", "Embarked_humanized"]) #values= "Survived"
# Out:
#                                    Age       Fare     Parch    Pclass  \
# Embarked Embarked_humanized
# C        Cherbourg           30.814769  59.954144  0.363095  1.886905
# Q        Queenstown          28.089286  13.276030  0.168831  2.909091
# S        Southampton         29.445397  27.079812  0.413043  2.350932
#
#                                 SibSp  Survived
# Embarked Embarked_humanized
# C        Cherbourg           0.386905  0.553571
# Q        Queenstown          0.428571  0.389610
# S        Southampton         0.571429  0.336957

# %% [markdown]
# ### 5. Embarked, Pclass 칼럼을 one-hot encoding

# %%
train[["Embarked","Pclass"]].head(2)
# Out:
#             Embarked  Pclass
# PassengerId
# 1                  S       3
# 2                  C       1

# %%
train.head(1)
# Out:
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#              Parch     Ticket  Fare Cabin Embarked Survived_humanized  \
# PassengerId
# 1                0  A/5 21171  7.25   NaN        S               dead
#
#             Pclass_humanized Embarked_humanized
# PassengerId
# 1                 ThirdClass        Southampton

# %%
df_Emb_dummies= pd.get_dummies(data= train.Embarked, prefix= 'Embarked')
df_Emb_dummies.head(2)
# Out:
#              Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# 1                     0           0           1
# 2                     1           0           0

# %%
df_Pcl_dummies= pd.get_dummies(data= train.Pclass, prefix= 'Pclass')
df_Pcl_dummies.head(2)
# Out:
#              Pclass_1  Pclass_2  Pclass_3
# PassengerId
# 1                   0         0         1
# 2                   1         0         0

# %% [markdown]
# 집어넣는 방법?
# - [insert](https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.insert.html) > train2.insert(loc= 11, column= 'Embarked_C', value= df_Emb_dummies['Embarked_C'])
#     - 하나는 적당. 그러나 여러개는 ..?
# - [append](https://stackoverflow.com/questions/41181779/merging-2-dataframes-vertically)
# - [concat](https://pandas.pydata.org/pandas-docs/stable/merging.html)
#     - pd.concat([train2, df_Emb_dummies, df_Pcl_dummies], sort=True, axis= 1)
#     - axis 없는 기본 값은 행 단위로 붙는거라, columns을 새로 넣을거면 axis= 1

# %%
# train2.drop('Embarked_C', axis=1, inplace= True)

# %%
train= pd.concat([train, df_Emb_dummies, df_Pcl_dummies], sort=True, axis= 1)

# %%
print(train.columns)
train.shape
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Survived_humanized', 'Pclass_humanized',
#        'Embarked_humanized', 'Embarked_C', 'Embarked_Q', 'Embarked_S',
#        'Pclass_1', 'Pclass_2', 'Pclass_3'],
#       dtype='object')
# (891, 20)

# %% [markdown]
# ### 6. Age컬럼에서 평균표준편차 민맥스 출력
# - [pandas var](http://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.DataFrame.var.html) ,  [표준편차](http://hidekuma.tistory.com/3)
# - 표준편차?

# %%
age_mean= train.Age.mean()
age_std= train.Age.std()
age_max= train.Age.max()
age_min= train.Age.min()

# %%
print(f"{age_mean:.3f}")
print(f"{age_std:.3f}")
print(f"{age_max:.3f}")
print(f"{age_min:.3f}")
# Out:
# 29.699
# 14.526
# 80.000
# 0.420

# %% [markdown]
# [statistics](http://www.scipy-lectures.org/packages/statistics/index.html)

# %%
from statsmodels.formula.api import ols

# %%
model= ols("Survived~Age", train).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     4.271
# Date:                Mon, 02 Jul 2018   Prob (F-statistic):             0.0391
# Time:                        11:27:36   Log-Likelihood:                -503.28
# No. Observations:                 714   AIC:                             1011.
# Df Residuals:                     712   BIC:                             1020.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4838      0.042     11.576      0.000       0.402       0.566
# Age           -0.0026      0.001     -2.067      0.039      -0.005      -0.000
# ==============================================================================
# Omnibus:                       16.419   Durbin-Watson:                   1.905
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              116.965
# Skew:                           0.380   Prob(JB):                     3.99e-26
# Kurtosis:                       1.168   Cond. No.                         75.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### 7.객실 등급별 Age평균
# 비싼 객실일 수록 평균 나이가 높구나

# %%
pd.pivot_table(data= train, index=['Pclass'], values='Age')
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %% [markdown]
# 데이터.groupby(['무슨칼럼별'])['대상칼럼'].함수

# %%
train.groupby(['Pclass'])['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %% [markdown]
# ### 8.나이를 범위별로 나눠서, 범위별 생존률
# 임의값: 15, 30 기준으로 나눠보자

# %%
train.loc[train.Survived[train.Age>=30], ""]
# Out:
# 0    196
# 1    134
# Name: Survived, dtype: int64

# %%
train.query('15<= Age and Age< 30')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 3                   1       3
# 9                   1       3
# 13                  0       3
# 23                  1       3
# 24                  1       1
# 28                  0       1
# 35                  0       1
# 38                  0       3
# 39                  0       3
# 42                  0       2
# 45                  1       3
# 50                  0       3
# 52                  0       3
# 54                  1       2
# 57                  1       2
# 58                  0       3
# 61                  0       3
# 67                  1       2
# 68                  0       3
# 69                  1       3
# 70                  0       3
# 72                  0       3
# 73                  0       2
# 74                  0       3
# 76                  0       3
# 81                  0       3
# 82                  1       3
# 84                  0       1
# 85                  1       2
# ...               ...     ...
# 811                 0       3
# 817                 0       3
# 822                 1       3
# 824                 1       3
# 831                 1       3
# 834                 0       3
# 835                 0       3
# 837                 0       3
# 841                 0       3
# 842                 0       2
# 845                 0       3
# 849                 0       2
# 854                 1       1
# 856                 1       3
# 859                 1       3
# 862                 0       2
# 865                 0       2
# 867                 1       2
# 871                 0       3
# 875                 1       2
# 876                 1       3
# 877                 0       3
# 878                 0       3
# 881                 1       2
# 883                 0       3
# 884                 0       2
# 885                 0       3
# 887                 0       2
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 13                              Saundercock, Mr. William Henry    male  20.0
# 23                                 McGowan, Miss. Anna "Annie"  female  15.0
# 24                                Sloper, Mr. William Thompson    male  28.0
# 28                              Fortune, Mr. Charles Alexander    male  19.0
# 35                                     Meyer, Mr. Edgar Joseph    male  28.0
# 38                                    Cann, Mr. Ernest Charles    male  21.0
# 39                          Vander Planke, Miss. Augusta Maria  female  18.0
# 42           Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0
# 45                               Devaney, Miss. Margaret Delia  female  19.0
# 50               Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0
# 52                                Nosworthy, Mr. Richard Cater    male  21.0
# 54           Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0
# 57                                           Rugg, Miss. Emily  female  21.0
# 58                                         Novel, Mr. Mansouer    male  28.5
# 61                                       Sirayanian, Mr. Orsen    male  22.0
# 67                                Nye, Mrs. (Elizabeth Ramell)  female  29.0
# 68                                    Crease, Mr. Ernest James    male  19.0
# 69                             Andersson, Miss. Erna Alexandra  female  17.0
# 70                                           Kink, Mr. Vincenz    male  26.0
# 72                                  Goodwin, Miss. Lillian Amy  female  16.0
# 73                                        Hood, Mr. Ambrose Jr    male  21.0
# 74                                 Chronopoulos, Mr. Apostolos    male  26.0
# 76                                     Moen, Mr. Sigurd Hansen    male  25.0
# 81                                        Waelens, Mr. Achille    male  22.0
# 82                                 Sheerlinck, Mr. Jan Baptist    male  29.0
# 84                                     Carrau, Mr. Francisco M    male  28.0
# 85                                         Ilett, Miss. Bertha  female  17.0
# ...                                                        ...     ...   ...
# 811                                     Alexander, Mr. William    male  26.0
# 817                               Heininen, Miss. Wendla Maria  female  23.0
# 822                                          Lulic, Mr. Nikola    male  27.0
# 824                                         Moor, Mrs. (Beila)  female  27.0
# 831                    Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 834                                     Augustsson, Mr. Albert    male  23.0
# 835                                     Allum, Mr. Owen George    male  18.0
# 837                                           Pasic, Mr. Jakob    male  21.0
# 841                                Alhomaki, Mr. Ilmari Rudolf    male  20.0
# 842                                   Mudd, Mr. Thomas Charles    male  16.0
# 845                                        Culumovic, Mr. Jeso    male  17.0
# 849                                          Harper, Rev. John    male  28.0
# 854                                  Lines, Miss. Mary Conover  female  16.0
# 856                                 Aks, Mrs. Sam (Leah Rosen)  female  18.0
# 859                      Baclini, Mrs. Solomon (Latifa Qurban)  female  24.0
# 862                                Giles, Mr. Frederick Edward    male  21.0
# 865                                     Gill, Mr. John William    male  24.0
# 867                               Duran y More, Miss. Asuncion  female  27.0
# 871                                          Balkic, Mr. Cerin    male  26.0
# 875                      Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# 876                           Najib, Miss. Adele Kiamie "Jane"  female  15.0
# 877                              Gustafsson, Mr. Alfred Ossian    male  20.0
# 878                                       Petroff, Mr. Nedelio    male  19.0
# 881               Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 883                               Dahlberg, Miss. Gerda Ulrika  female  22.0
# 884                              Banfield, Mr. Frederick James    male  28.0
# 885                                     Sutehall, Mr. Henry Jr    male  25.0
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
#
#              SibSp  Parch            Ticket      Fare        Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171    7.2500          NaN        S
# 3                0      0  STON/O2. 3101282    7.9250          NaN        S
# 9                0      2            347742   11.1333          NaN        S
# 13               0      0         A/5. 2151    8.0500          NaN        S
# 23               0      0            330923    8.0292          NaN        Q
# 24               0      0            113788   35.5000           A6        S
# 28               3      2             19950  263.0000  C23 C25 C27        S
# 35               1      0          PC 17604   82.1708          NaN        C
# 38               0      0        A./5. 2152    8.0500          NaN        S
# 39               2      0            345764   18.0000          NaN        S
# 42               1      0             11668   21.0000          NaN        S
# 45               0      0            330958    7.8792          NaN        Q
# 50               1      0            349237   17.8000          NaN        S
# 52               0      0        A/4. 39886    7.8000          NaN        S
# 54               1      0              2926   26.0000          NaN        S
# 57               0      0        C.A. 31026   10.5000          NaN        S
# 58               0      0              2697    7.2292          NaN        C
# 61               0      0              2669    7.2292          NaN        C
# 67               0      0        C.A. 29395   10.5000          F33        S
# 68               0      0         S.P. 3464    8.1583          NaN        S
# 69               4      2           3101281    7.9250          NaN        S
# 70               2      0            315151    8.6625          NaN        S
# 72               5      2           CA 2144   46.9000          NaN        S
# 73               0      0      S.O.C. 14879   73.5000          NaN        S
# 74               1      0              2680   14.4542          NaN        C
# 76               0      0            348123    7.6500        F G73        S
# 81               0      0            345767    9.0000          NaN        S
# 82               0      0            345779    9.5000          NaN        S
# 84               0      0            113059   47.1000          NaN        S
# 85               0      0        SO/C 14885   10.5000          NaN        S
# ...            ...    ...               ...       ...          ...      ...
# 811              0      0              3474    7.8875          NaN        S
# 817              0      0  STON/O2. 3101290    7.9250          NaN        S
# 822              0      0            315098    8.6625          NaN        S
# 824              0      1            392096   12.4750         E121        S
# 831              1      0              2659   14.4542          NaN        C
# 834              0      0            347468    7.8542          NaN        S
# 835              0      0              2223    8.3000          NaN        S
# 837              0      0            315097    8.6625          NaN        S
# 841              0      0  SOTON/O2 3101287    7.9250          NaN        S
# 842              0      0       S.O./P.P. 3   10.5000          NaN        S
# 845              0      0            315090    8.6625          NaN        S
# 849              0      1            248727   33.0000          NaN        S
# 854              0      1          PC 17592   39.4000          D28        S
# 856              0      1            392091    9.3500          NaN        S
# 859              0      3              2666   19.2583          NaN        C
# 862              1      0             28134   11.5000          NaN        S
# 865              0      0            233866   13.0000          NaN        S
# 867              1      0     SC/PARIS 2149   13.8583          NaN        C
# 871              0      0            349248    7.8958          NaN        S
# 875              1      0         P/PP 3381   24.0000          NaN        C
# 876              0      0              2667    7.2250          NaN        C
# 877              0      0              7534    9.8458          NaN        S
# 878              0      0            349212    7.8958          NaN        S
# 881              0      1            230433   26.0000          NaN        S
# 883              0      0              7552   10.5167          NaN        S
# 884              0      0  C.A./SOTON 34068   10.5000          NaN        S
# 885              0      0   SOTON/OQ 392076    7.0500          NaN        S
# 887              0      0            211536   13.0000          NaN        S
# 888              0      0            112053   30.0000          B42        S
# 890              0      0            111369   30.0000         C148        C
#
#             Survived_humanized Pclass_humanized Embarked_humanized  \
# PassengerId
# 1                         dead       ThirdClass        Southampton
# 3                         live       ThirdClass        Southampton
# 9                         live       ThirdClass        Southampton
# 13                        dead       ThirdClass        Southampton
# 23                        live       ThirdClass         Queenstown
# 24                        live       FirstClass        Southampton
# 28                        dead       FirstClass        Southampton
# 35                        dead       FirstClass          Cherbourg
# 38                        dead       ThirdClass        Southampton
# 39                        dead       ThirdClass        Southampton
# 42                        dead      SecondClass        Southampton
# 45                        live       ThirdClass         Queenstown
# 50                        dead       ThirdClass        Southampton
# 52                        dead       ThirdClass        Southampton
# 54                        live      SecondClass        Southampton
# 57                        live      SecondClass        Southampton
# 58                        dead       ThirdClass          Cherbourg
# 61                        dead       ThirdClass          Cherbourg
# 67                        live      SecondClass        Southampton
# 68                        dead       ThirdClass        Southampton
# 69                        live       ThirdClass        Southampton
# 70                        dead       ThirdClass        Southampton
# 72                        dead       ThirdClass        Southampton
# 73                        dead      SecondClass        Southampton
# 74                        dead       ThirdClass          Cherbourg
# 76                        dead       ThirdClass        Southampton
# 81                        dead       ThirdClass        Southampton
# 82                        live       ThirdClass        Southampton
# 84                        dead       FirstClass        Southampton
# 85                        live      SecondClass        Southampton
# ...                        ...              ...                ...
# 811                       dead       ThirdClass        Southampton
# 817                       dead       ThirdClass        Southampton
# 822                       live       ThirdClass        Southampton
# 824                       live       ThirdClass        Southampton
# 831                       live       ThirdClass          Cherbourg
# 834                       dead       ThirdClass        Southampton
# 835                       dead       ThirdClass        Southampton
# 837                       dead       ThirdClass        Southampton
# 841                       dead       ThirdClass        Southampton
# 842                       dead      SecondClass        Southampton
# 845                       dead       ThirdClass        Southampton
# 849                       dead      SecondClass        Southampton
# 854                       live       FirstClass        Southampton
# 856                       live       ThirdClass        Southampton
# 859                       live       ThirdClass          Cherbourg
# 862                       dead      SecondClass        Southampton
# 865                       dead      SecondClass        Southampton
# 867                       live      SecondClass          Cherbourg
# 871                       dead       ThirdClass        Southampton
# 875                       live      SecondClass          Cherbourg
# 876                       live       ThirdClass          Cherbourg
# 877                       dead       ThirdClass        Southampton
# 878                       dead       ThirdClass        Southampton
# 881                       live      SecondClass        Southampton
# 883                       dead       ThirdClass        Southampton
# 884                       dead      SecondClass        Southampton
# 885                       dead       ThirdClass        Southampton
# 887                       dead      SecondClass        Southampton
# 888                       live       FirstClass        Southampton
# 890                       live       FirstClass          Cherbourg
#
#              Embarked_C  Embarked_Q  Embarked_S  Pclass_1  Pclass_2  Pclass_3
# PassengerId
# 1                     0           0           1         0         0         1
# 3                     0           0           1         0         0         1
# 9                     0           0           1         0         0         1
# 13                    0           0           1         0         0         1
# 23                    0           1           0         0         0         1
# 24                    0           0           1         1         0         0
# 28                    0           0           1         1         0         0
# 35                    1           0           0         1         0         0
# 38                    0           0           1         0         0         1
# 39                    0           0           1         0         0         1
# 42                    0           0           1         0         1         0
# 45                    0           1           0         0         0         1
# 50                    0           0           1         0         0         1
# 52                    0           0           1         0         0         1
# 54                    0           0           1         0         1         0
# 57                    0           0           1         0         1         0
# 58                    1           0           0         0         0         1
# 61                    1           0           0         0         0         1
# 67                    0           0           1         0         1         0
# 68                    0           0           1         0         0         1
# 69                    0           0           1         0         0         1
# 70                    0           0           1         0         0         1
# 72                    0           0           1         0         0         1
# 73                    0           0           1         0         1         0
# 74                    1           0           0         0         0         1
# 76                    0           0           1         0         0         1
# 81                    0           0           1         0         0         1
# 82                    0           0           1         0         0         1
# 84                    0           0           1         1         0         0
# 85                    0           0           1         0         1         0
# ...                 ...         ...         ...       ...       ...       ...
# 811                   0           0           1         0         0         1
# 817                   0           0           1         0         0         1
# 822                   0           0           1         0         0         1
# 824                   0           0           1         0         0         1
# 831                   1           0           0         0         0         1
# 834                   0           0           1         0         0         1
# 835                   0           0           1         0         0         1
# 837                   0           0           1         0         0         1
# 841                   0           0           1         0         0         1
# 842                   0           0           1         0         1         0
# 845                   0           0           1         0         0         1
# 849                   0           0           1         0         1         0
# 854                   0           0           1         1         0         0
# 856                   0           0           1         0         0         1
# 859                   1           0           0         0         0         1
# 862                   0           0           1         0         1         0
# 865                   0           0           1         0         1         0
# 867                   1           0           0         0         1         0
# 871                   0           0           1         0         0         1
# 875                   1           0           0         0         1         0
# 876                   1           0           0         0         0         1
# 877                   0           0           1         0         0         1
# 878                   0           0           1         0         0         1
# 881                   0           0           1         0         1         0
# 883                   0           0           1         0         0         1
# 884                   0           0           1         0         1         0
# 885                   0           0           1         0         0         1
# 887                   0           0           1         0         1         0
# 888                   0           0           1         1         0         0
# 890                   1           0           0         1         0         0
#
# [306 rows x 20 columns]

# %% [markdown]
# ---
# 이하: 어떻게 생긴지 봄

# %%
from statsmodels.formula.api import ols

# %%
model= ols("Survived~Age", data= train).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     4.271
# Date:                Mon, 02 Jul 2018   Prob (F-statistic):             0.0391
# Time:                        11:52:20   Log-Likelihood:                -503.28
# No. Observations:                 714   AIC:                             1011.
# Df Residuals:                     712   BIC:                             1020.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4838      0.042     11.576      0.000       0.402       0.566
# Age           -0.0026      0.001     -2.067      0.039      -0.005      -0.000
# ==============================================================================
# Omnibus:                       16.419   Durbin-Watson:                   1.905
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              116.965
# Skew:                           0.380   Prob(JB):                     3.99e-26
# Kurtosis:                       1.168   Cond. No.                         75.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# [왜도 첨도](https://www.google.co.kr/search?q=%EC%99%9C%EB%8F%84+%EC%B2%A8%EB%8F%84&newwindow=1&source=lnms&tbm=isch&sa=X&ved=0ahUKEwjTlY7Utf_bAhVFMt4KHTgYBQUQ_AUICigB&biw=931&bih=994#imgrc=Zv8cdfkfoiYgsM:)
# - 왜도 Skewness. 양수면 왼쪽으로 쏠려있는 데이터(오른쪽으로 꼬리가 긴)
#     - 중앙값 median < 평균 mean
# - 첨도 Kurtosis. 양수면 정규분포보다 뾰족

# %%
print('{0:.3f}'.format(train.Age.mean()))
# Out:
# 29.699

# %%
print('%.3f'%train.Age.mean())
# Out:
# 29.699

# %%
train.Age.median()
# Out:
# 28.0

# %%
print(train.Age.max())
print(train.Age.min())
# Out:
# 80.0
# 0.42

# %%
import seaborn as sns
# %matpotlib inline

# %%
sns.countplot(data= train, x= "Age", )
