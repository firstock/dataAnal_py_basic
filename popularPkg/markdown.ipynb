# %% [markdown]
# ## Markdown

# %% [markdown]
# - <https://gist.github.com/ihoneymon/652be052a0727ad59601>
# - https://gist.github.com/ihoneymon/652be052a0727ad59601
# - [markdown_syntax](<https://gist.github.com/ihoneymon/652be052a0727ad59601>)

# %% [markdown]
# * ㅁㄴㅇㄹ
#     * ㅁㄴㅇㄹ
# + 1234
#     + 1234
# - !@#
#     - !@#
#         - %^&

# %% [markdown]
# <hr/>
# > ㅇ__ㅁ__ㅇ
# > ㅇ**ㅂ**ㅇ
# > ㅇ_ㅅ_ㅇ
# > ㅇ*ㅈ*ㅇ
# - ~~ㅇㅇ   ~~
# - ~~ㅇㅇ~~
# 1. ㅁㄴㅇㄹ
#     1. ㅁㄴㅇㄹ
#         1.ㅁㄴㅇㄹ

# %% [markdown]
# ---

# %% [markdown]
# [table maker](http://www.tablesgenerator.com/markdown_tables)
# - table 제작
#     - http://www.tablesgenerator.com/markdown_tables

# %% [markdown]
# |믕   |   |   |   |   |
# |---|---|---|---|---|
# |   |몽   |   |   |   |
# |   |   |   |뫙   |   |
# |   |   | 뭉 |   |   |

# %% [markdown]
# ![image.png](attachment:image.png)
